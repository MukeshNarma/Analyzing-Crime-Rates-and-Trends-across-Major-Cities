# %% [markdown]
# <a href="https://colab.research.google.com/github/MukeshNarma/Analyzing-Crime-Rates-and-Trends-across-Major-Cities/blob/main/DATAEXPLORATIONANDVISULISATIONBASICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'Gender': ['Male', 'Female', 'Male', 'Female', 'Female'],
        'Education': ['High School', 'Bachelor', 'Bachelor', 'PhD', 'Master'],
        'Employment': ['Employed', 'Unemployed', 'Employed', 'Unemployed', 'Employed']}

df = pd.DataFrame(data)

# Create three-variable contingency table
table = pd.crosstab([df['Gender'], df['Education']], df['Employment'])
print(table)
import matplotlib.pyplot as plt
import seaborn as sns

# Simulated data
df = pd.DataFrame({
    'Trust': [4, 3, 5, 2, 4, 5, 3, 2, 4],
    'Reciprocity': [3, 2, 5, 1, 4, 5, 3, 2, 4]
})

# Scatterplot to visualize relationship
plt.figure(figsize=(8, 6))
sns.regplot(x='Trust', y='Reciprocity', data=df)
plt.title('Trust vs Reciprocity')
plt.show()
# Out:
# Employment          Employed  Unemployed
# Gender Education
# Female Bachelor            0           1
#        Master              1           0
#        PhD                 0           1
# Male   Bachelor            1           0
#        High School         1           0

# %%
import statsmodels.api as sm

# Simulated data
df = pd.DataFrame({
    'Education': [10, 12, 16, 14, 18],
    'Experience': [5, 6, 8, 10, 12],
    'Income': [50, 60, 80, 70, 100]
})

# Add constant for intercept
X = df[['Education', 'Experience']]
X = sm.add_constant(X)
y = df['Income']

# Regression model controlling for Experience
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Income   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.953
# Method:                 Least Squares   F-statistic:                     41.29
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):             0.0236
# Time:                        04:57:27   Log-Likelihood:                -11.959
# No. Observations:                   5   AIC:                             29.92
# Df Residuals:                       2   BIC:                             28.75
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -9.5000     10.542     -0.901      0.463     -54.857      35.857
# Education      5.3333      1.412      3.778      0.063      -0.741      11.408
# Experience     0.8333      1.559      0.535      0.646      -5.875       7.541
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.750
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.506
# Skew:                          -0.081   Prob(JB):                        0.776
# Kurtosis:                       1.450   Cond. No.                         94.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create causal path model using a directed graph
G = nx.DiGraph()

# Adding nodes and edges
G.add_edges_from([('Education', 'Occupation'), ('Occupation', 'Income'), ('Education', 'Income')])

# Draw the graph
plt.figure(figsize=(6, 4))
nx.draw(G, with_labels=True, node_color='lightblue', node_size=3000, font_size=10, font_weight='bold')
plt.title('Causal Path Model: Education, Occupation, Income')
plt.show()

# %%
import statsmodels.formula.api as smf

# Simulated data
df = pd.DataFrame({
    'Education': [10, 12, 16, 14, 18],
    'Experience': [5, 6, 8, 10, 12],
    'Income': [50, 60, 80, 70, 100],
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male']
})

# Fit model with interaction between Education and Gender
model = smf.ols('Income ~ Education * Gender', data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Income   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                     13.92
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):              0.194
# Time:                        05:22:27   Log-Likelihood:                -11.932
# No. Observations:                   5   AIC:                             31.86
# Df Residuals:                       1   BIC:                             30.30
# Df Model:                           3
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                 2.304e-14     54.243   4.25e-16      1.000    -689.223     689.223
# Gender[T.Male]             -10.7692     56.291     -0.191      0.880    -726.010     704.471
# Education                    5.0000      4.160      1.202      0.442     -47.861      57.861
# Education:Gender[T.Male]     0.9615      4.279      0.225      0.859     -53.403      55.326
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.615
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.359
# Skew:                          -0.607   Prob(JB):                        0.836
# Kurtosis:                       2.500   Cond. No.                         521.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "

# %%
import statsmodels.api as sm

# Simulated binary outcome
df = pd.DataFrame({
    'Education': [10, 12, 16, 14, 18],
    'Experience': [5, 6, 8, 10, 12],
    'Employed': [1, 0, 1, 1, 0]
})

# Logistic regression model
X = df[['Education', 'Experience']]
X = sm.add_constant(X)
y = df['Employed']

model = sm.Logit(y, X).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.630235
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Employed   No. Observations:                    5
# Model:                          Logit   Df Residuals:                        2
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 05 Nov 2024   Pseudo R-squ.:                 0.06356
# Time:                        05:23:02   Log-Likelihood:                -3.1512
# converged:                       True   LL-Null:                       -3.3651
# Covariance Type:            nonrobust   LLR p-value:                    0.8074
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.5105      5.549      0.633      0.527      -7.364      14.385
# Education     -0.2171      0.694     -0.313      0.754      -1.576       1.142
# Experience    -0.0033      0.758     -0.004      0.996      -1.488       1.482
# ==============================================================================

# %%
print(model.params)
# Out:
# const         3.510522
# Education    -0.217122
# Experience   -0.003324
# dtype: float64

# %%
df = pd.DataFrame({
    'Age': [25, 35, 45, 55, 65],
    'Cohort': [1990, 1980, 1970, 1960, 1950],
    'Income': [40, 50, 60, 70, 80]
})

# Model to assess age and cohort effects
model = smf.ols('Income ~ Age + Cohort', data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Income   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.731e+28
# Date:                Tue, 05 Nov 2024   Prob (F-statistic):           9.68e-43
# Time:                        05:23:43   Log-Likelihood:                 139.47
# No. Observations:                   5   AIC:                            -274.9
# Df Residuals:                       3   BIC:                            -275.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0005    3.6e-18    1.4e+14      0.000       0.001       0.001
# Age            1.0074   7.43e-15   1.36e+14      0.000       1.007       1.007
# Cohort         0.0074   1.78e-16   4.18e+13      0.000       0.007       0.007
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.001
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.888
# Skew:                           1.500   Prob(JB):                        0.389
# Kurtosis:                       3.250   Cond. No.                     1.03e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.82e-31. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /usr/local/lib/python3.10/dist-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
